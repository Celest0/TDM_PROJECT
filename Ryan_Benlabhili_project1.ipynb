# %% [markdown]
# # Project 1 -- Ryan Benlabhili

# %% [markdown]
# **TA Help:** NONE
#
# **Collaboration:** ME
#
#
#
# **Internet Resources:** NONE
#
# **ChatGPT, Gemini, Claude, etc:** CHATGPT.
#
#
#
# **OVERALL MESSAGE:**  CHECK
#
# **YOUR OWN WORK:** DONE

# %% [markdown]
# ## Question 1

# %%
# shows the first 6 
%%R
myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(myDF)
# Out:
#   iata              airport             city state country      lat       long
# 1  00M             Thigpen       Bay Springs    MS     USA 31.95376  -89.23450
# 2  00R Livingston Municipal       Livingston    TX     USA 30.68586  -95.01793
# 3  00V          Meadow Lake Colorado Springs    CO     USA 38.94575 -104.56989
# 4  01G         Perry-Warsaw            Perry    NY     USA 42.74135  -78.05208
# 5  01J     Hilliard Airpark         Hilliard    FL     USA 30.68801  -81.90594
# 6  01M    Tishomingo County          Belmont    MS     USA 34.49167  -88.20111

# %%
%%R
head(myDF, n=12)
# Out:
#    iata              airport             city state country      lat       long
# 1   00M             Thigpen       Bay Springs    MS     USA 31.95376  -89.23450
# 2   00R Livingston Municipal       Livingston    TX     USA 30.68586  -95.01793
# 3   00V          Meadow Lake Colorado Springs    CO     USA 38.94575 -104.56989
# 4   01G         Perry-Warsaw            Perry    NY     USA 42.74135  -78.05208
# 5   01J     Hilliard Airpark         Hilliard    FL     USA 30.68801  -81.90594
# 6   01M    Tishomingo County          Belmont    MS     USA 34.49167  -88.20111
# 7   02A          Gragg-Wade           Clanton    AL     USA 32.85049  -86.61145
# 8   02C              Capitol       Brookfield    WI     USA 43.08751  -88.17787
# 9   02G    Columbiana County   East Liverpool    OH     USA 40.67331  -80.64141
# 10  03D     Memphis Memorial          Memphis    MO     USA 40.44726  -92.22696
# 11  04M       Calhoun County        Pittsboro    MS     USA 33.93011  -89.34285
# ...

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
#switched to seminar r
myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(myDF)
# Out:
#   iata airport              city             state country lat      long
# 1 00M  Thigpen              Bay Springs      MS    USA     31.95376  -89.23450
# 2 00R  Livingston Municipal Livingston       TX    USA     30.68586  -95.01793
# 3 00V  Meadow Lake          Colorado Springs CO    USA     38.94575 -104.56989
# 4 01G  Perry-Warsaw         Perry            NY    USA     42.74135  -78.05208
# 5 01J  Hilliard Airpark     Hilliard         FL    USA     30.68801  -81.90594
# 6 01M  Tishomingo County    Belmont          MS    USA     34.49167  -88.20111

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 3

# %%
myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/2007.csv")

# %%
library(data.table)

# %%
myDF <- fread("/anvil/projects/tdm/data/flights/subset/2007.csv")

# %%
options(repr.matrix.max.cols=50)

# %%
head(myDF)
# Out:
#   Year Month DayofMonth DayOfWeek DepTime CRSDepTime ArrTime CRSArrTime
# 1 2007 1     1          1         1232    1225       1341    1340
# 2 2007 1     1          1         1918    1905       2043    2035
# 3 2007 1     1          1         2206    2130       2334    2300
# 4 2007 1     1          1         1230    1200       1356    1330
# 5 2007 1     1          1          831     830        957    1000
# 6 2007 1     1          1         1430    1420       1553    1550
#   UniqueCarrier FlightNum TailNum ActualElapsedTime CRSElapsedTime AirTime
# 1 WN            2891      N351    69                75             54
# 2 WN             462      N370    85                90             74
# 3 WN            1229      N685    88                90             73
# 4 WN            1355      N364    86                90             75
# 5 WN            2278      N480    86                90             74
# 6 WN            2386      N611SW  83                90             74
# ...

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %%
dim(myDF)
# Out:
# [1] 7453215      29

# %%
head(myDF$Origin, n=300)
# Out:
#   [1] "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF"
#  [13] "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF"
#  [25] "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF"
#  [37] "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA"
#  [49] "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA"
#  [61] "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA" "SNA"
#  [73] "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL"
#  [85] "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL"
#  [97] "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL"
# [109] "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL"
# [121] "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL" "STL"
# [133] "STL" "STL" "STL" "TPA" "TPA" "TPA" "TPA" "TPA" "TPA" "TPA" "TPA" "TPA"
# ...

# %%
#lets 30 to pull up 30 this time SMF wins top 20
head(myDF$Origin, n=20)
# Out:
#  [1] "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF"
# [13] "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF" "SMF"

# %% [markdown]
# ## Question 4

# %%
library(data.table)

# Load the data
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")

# Count occurrences of each City and sort
top_cities <- myDF[, .N, by = City][order(-N)][1:10]

# Show the result
top_cities
# Out:
#    City           N
# 1  London         22426
# 2  Athina         15556
# 3  Sydney         13821
# 4  Atlanta        13780
# 5  Rio de Janeiro 13688
# 6  Beijing        13602
# 7  Barcelona      12977
# 8  Los Angeles    12423
# 9  Seoul          12037
# 10 Munich         10304

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
# Count and sort
origin_counts <- table(flightsDF$Origin)
top20 <- sort(origin_counts, decreasing = TRUE)[1:20]

# Convert to numeric, keep airport codes as labels
dotchart(as.numeric(top20),
         labels = names(top20),
         main = "Top 20 Origin Airports (2007 Flights)",
         xlab = "Number of Flights")
# Out:
# Plot with title "Top 20 Origin Airports (2007 Flights)"

# %%
# Count city occurrences
city_counts <- table(myDF$City)

# Sort and take top 20
top20 <- sort(city_counts, decreasing = TRUE)[1:20]

# Dotchart with numeric values + labels
dotchart(as.numeric(top20),
         labels = names(top20),
         main = "Top 20 Olympic Cities",
         xlab = "Frequency")
# Out:
# Plot with title "Top 20 Olympic Cities"

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
